# %%
# read https://raw.githubusercontent.com/VolkiTheDreamer/dataset/refs/heads/master/Text/big.txt
import requests
url = "https://raw.githubusercontent.com/VolkiTheDreamer/dataset/refs/heads/master/Text/big.txt"
response = requests.get(url)
text = response.text

# %%
len(text)
# Out:
# 6488666

# %%
text[:100]
# Out:
# 'The Project Gutenberg EBook of The Adventures of Sherlock Holmes\nby Sir Arthur Conan Doyle\n(#15 in o'

# %%
#NLP, nltk, spacy, gensim

# %%
#count the number of spaces in the text
text.count(' ')+1
# Out:
# 1036511

# %%
"volkan yurtseven".count(' ')+1
# Out:
# 2

# %%
"volkan yurtseven".split(" ")
# Out:
# ['volkan', 'yurtseven']

# %%
len("volkan yurtseven".split(" "))
# Out:
# 2

# %%
len(text.split(" "))
# Out:
# 1036512

# %%
words = text.split(" ")

# %%
words[:10]
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'The',
#  'Adventures',
#  'of',
#  'Sherlock',
#  'Holmes\nby']

# %%
#son 10 kelime
words[-10:]
# Out:
# ['', 'print', 's\n', '', 'print', '[ord(c)', 'for', 'c', 'in', 's]\n']

# %%
#son kelime
words[-1]
# Out:
# 's]\n'

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
for p in string.punctuation:
    text = text.replace(p, " ")

# %%
words = text.split(" ")
len(words)
# Out:
# 1253601

# %%
words[-10:]
# Out:
# ['print', '', 'ord', 'c', '', 'for', 'c', 'in', 's', '\n']

# %%
from collections import Counter
Counter(words).most_common(25)
#top 25 kelime ve frekansı
# Out:
# [('', 193853),
#  ('the', 61702),
#  ('of', 35284),
#  ('and', 31860),
#  ('to', 25238),
#  ('in', 17896),
#  ('a', 17850),
#  ('that', 10549),
#  ('was', 9970),
#  ('\n\n', 9740),
#  ('he', 8997),
#  ('is', 8635),
#  ('his', 8275),
#  ('with', 8249),
#  ('it', 7784),
#  ('I', 7286),
#  ('as', 6727),
#  ('had', 6380),
#  ('for', 5887),
#  ('by', 5716),
#  ('not', 5708),
#  ('at', 5692),
#  ('on', 5420),
#  ('be', 5363),
#  ('s', 5143)]

# %%
pwd="volkan1234"

# %%
encrypted = "".join([chr(ord(x)+1) for x in pwd])

# %%
decrypeted = "".join([chr(ord(x)-1) for x in encrypted])
decrypeted
# Out:
# 'volkan1234'
